# %% [markdown]
# # 库导入

# %%
# -*- coding: utf-8 -*-
import networkx as nx
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, average_precision_score, matthews_corrcoef
)
import random
import os
import pandas as pd

# %% [markdown]
# # 待调用的函数

# %%
# 0. 评价指标计算函数
def evaluate_metrics(y_true, y_scores):
    # 动态阈值：使用阳性分数中位数作为阈值（若没有阳性分数则取0）
    threshold = np.median([s for s in y_scores if s > 0]) if any(y_scores) else 0
    y_pred = [int(score > threshold) for score in y_scores]
    return {
        'accuracy': accuracy_score(y_true, y_pred),
        'precision': precision_score(y_true, y_pred, zero_division=0),
        'recall': recall_score(y_true, y_pred, zero_division=0),
        'f1': f1_score(y_true, y_pred, zero_division=0),
        'roc_auc': roc_auc_score(y_true, y_scores),
        'average_precision': average_precision_score(y_true, y_scores),
        'mcc': matthews_corrcoef(y_true, y_pred)
    }

# 4. 预先构建结构特征
def precompute_structural_features(G, edge_list, structural_features):
    """
    预计算给定图G中若干边的结构特征，避免重复计算。
    返回字典：{(u,v): [feat1, feat2, ...]}，顺序与structural_features参数对应。
    """
    feature_dict = {}
    neighbors = {n: set(G.neighbors(n)) for n in G.nodes()}
    degrees = dict(G.degree())
    for u, v in edge_list:
        # 确保无向边用有序元组表示
        u, v = tuple(sorted((u, v)))
        Nu, Nv = neighbors[u], neighbors[v]
        inter = Nu & Nv        # 公共邻居集合
        union = Nu | Nv        # 邻居并集
        feature_values = []
        for feat in structural_features:
            if feat == 'CN':
                # Common Neighbors 数量
                feature_values.append(len(inter))
            elif feat == 'JC':
                # Jaccard 系数 = 公共邻居数 / 并集邻居数
                feature_values.append(len(inter) / len(union) if union else 0.0)
            elif feat == 'AA':
                # Adamic-Adar 指数 = Σ(1/log(deg(w))) for w in 公共邻居
                aa_score = sum(1 / np.log(degrees[w]) for w in inter if degrees[w] > 1)
                feature_values.append(aa_score)
            elif feat == 'PA':
                # Preferential Attachment = 度数乘积
                feature_values.append(degrees[u] * degrees[v])
            elif feat == 'HI':
                # 自定义指标：度数差绝对值 (Hub Index 或其他定义)
                feature_values.append(abs(degrees[u] - degrees[v]))
            elif feat == 'RA':
                # Resource Allocation 指数 = Σ(1/deg(w)) for w in 公共邻居
                ra_score = sum(1 / degrees[w] for w in inter) if inter else 0.0
                feature_values.append(ra_score)
            else:
                # 如果传入了未定义的特征编码，则填0占位
                feature_values.append(0.0)
        feature_dict[(u, v)] = np.array(feature_values, dtype=float)
    return feature_dict

# 5. 五折交叉验证进行链路预测评估
def link_prediction_cross_validation(G, structural_features):
    """
    对图G进行5折交叉验证的链路预测实验，使用指定的结构特征集合。
    参数:
        G: 原始完整图 (networkx.Graph)
        structural_features: 元组或列表，指定使用的结构特征 (例如 ('CN','JC','AA','PA'))
    返回:
        avg_results: 每种特征的平均评价指标字典，例如{'CN': {'accuracy': ..., ...}, 'JC': {...}, ...}
    """
    all_positive_edges = list(G.edges())
    kf = KFold(n_splits=5, shuffle=True)
    # 动态初始化每种特征的度量结果列表
    fold_metrics = {feat: [] for feat in structural_features}

    for fold, (train_idx, test_idx) in enumerate(kf.split(all_positive_edges), start=1):
        print(f"\n----- Fold {fold}/5 -----")
        # 划分训练集和测试集的正样本边
        train_pos_edges = [all_positive_edges[i] for i in train_idx]
        test_pos_edges = [all_positive_edges[i] for i in test_idx]
        # 构建训练子图（移除测试集正边，避免信息泄漏）
        G_train = nx.Graph()
        G_train.add_nodes_from(G.nodes())         # 保留所有节点
        G_train.add_edges_from(train_pos_edges)   # 添加训练正样本边

        # 准备测试集负样本边（不存在于原图的随机边，数量与测试正样本相同）
        existing_edges = set(tuple(sorted(edge)) for edge in G.edges())
        test_neg_edges = []
        nodes = list(G.nodes())
        while len(test_neg_edges) < len(test_pos_edges):
            u, v = random.choice(nodes), random.choice(nodes)
            if u == v:
                continue
            pair = tuple(sorted((u, v)))
            if pair in existing_edges or pair in test_neg_edges:
                continue
            test_neg_edges.append(pair)

        # 合并测试边集（正样本边 + 负样本边）
        test_edges = [tuple(sorted(e)) for e in test_pos_edges] + test_neg_edges
        # 基于训练子图预计算所有测试边的结构特征
        features = precompute_structural_features(G_train, test_edges, structural_features)
        # 构建标签列表（1表示正样本边，0表示负样本边）
        y_true = [1] * len(test_pos_edges) + [0] * len(test_neg_edges)

        # 初始化每种特征的评分列表
        score_lists = {feat: [] for feat in structural_features}
        # 将每条测试边对应的特征值加入各自的评分列表
        for edge in test_edges:
            feature_values = features[tuple(sorted(edge))]
            for idx, feat in enumerate(structural_features):
                score_lists[feat].append(feature_values[idx])

        # 计算每种特征方法在当前折的指标，并保存结果
        for feat in structural_features:
            metrics = evaluate_metrics(y_true, score_lists[feat])
            fold_metrics[feat].append(metrics)
            print(f"{feat} - 折{fold}结果: {metrics}")

    # 计算5折平均结果
    avg_results = {}
    for feat, metrics_list in fold_metrics.items():
        avg_results[feat] = {}
        for metric_name in metrics_list[0].keys():
            # 计算该特征在所有折上的平均值
            values = [fold_result[metric_name] for fold_result in metrics_list]
            avg_results[feat][metric_name] = float(np.mean(values))
    return avg_results

# %% [markdown]
# # 主函数

# %%
######### 参数设置 #########
dataset_name = "facebook"  # 可替换为其他数据集名称
edges_file_path = f"norm_dataset/{dataset_name}_edges.txt"
G = nx.read_edgelist(edges_file_path, nodetype=int)

# 可调节的结构特征列表，例如只选择部分特征或增加新特征
structural_features = ('RA','CN','JC','AA','PA','HI')
runs = 10  # 重复实验次数

# 主运行：多次重复实验以获取平均结果
all_rows = []
for run in range(runs):
    print(f"\n=== 运行 {run + 1}/{runs} ===")
    results = link_prediction_cross_validation(G, structural_features=structural_features)
    # 将结果整理为一行记录
    row_data = {}
    for feat, metrics in results.items():
        for metric, value in metrics.items():
            col_name = f"{feat}_{metric}"
            row_data[col_name] = round(value, 4)
    all_rows.append(row_data)
    print(f"第 {run+1} 次运行结果: {row_data}")

# 保存结果到 Excel 文件
output_dir = f"results_baseline/{dataset_name}"
os.makedirs(output_dir, exist_ok=True)
param_str = "_".join(structural_features)
file_name = f"{dataset_name}_{param_str}.xlsx"
file_path = os.path.join(output_dir, file_name)

# 如果文件已存在则追加，否则创建新文件
if os.path.exists(file_path):
    existing = pd.read_excel(file_path)
    df = pd.concat([existing, pd.DataFrame(all_rows)], ignore_index=True)
else:
    df = pd.DataFrame(all_rows)
df.to_excel(file_path, index=False)
print(f"✅ 实验结果已保存至: {file_name}")
# Out:
# === 运行 1/10 ===
#
# ----- Fold 1/5 -----
# RA - 折1结果: {'accuracy': 0

#
# ----- Fold 5/5 -----
# RA - 折5结果: {'accuracy': 0.7781083531678568, 'precision': 0.9983751396364375, 'recall': 0.5571234274056444, 'f1': 0.7151638598916088, 'roc_auc': 0.9934497033213129, 'average_precision': 0.9933113425083129, 'mcc': 0.6200648420717648}
# CN - 折5结果: {'accuracy': 0.7710812648758926, 'precision': 0.9954427757638529, 'recall': 0.544656012694095, 'f1': 0.7040767737445515, 'roc_auc': 0.991227140616234, 'average_precision': 0.989395920569528, 'mcc': 0.6080874400361427}
# JC - 折5结果: {'accuracy': 0.774708149155616, 'precision': 0.9967209755097859, 'recall': 0.5512297404510937, 'f1': 0.7098704615945995, 'roc_auc': 0.989442987324262, 'average_precision': 0.9883549471485472, 'mcc': 0.6141779659757048}
# AA - 折5结果: {'accuracy': 0.7768616116967018, 'precision': 0.996140956636539, 'recall': 0.5558766859344894, 'f1': 0.7135634525151857, 'roc_auc': 0.9923620609914822, 'average_precision': 0.9916691633066617, 'mcc': 0.6172851321327778}
# PA - 折5结果: {'accuracy': 0.7555536665533266, 'precision': 0.7567029088632095, 'recall': 0.7533151989119348, 'f1': 0.755005253741516, 'roc_auc': 0.8356139020878184, 'average_precision': 0.8512321445397057, 'mcc': 0.5111124552328901}
# HI - 折5结果: {'accuracy': 0.50291850844384, 'precision': 0.5030210594239456, 'recall': 0.4859458234160716, 'f1': 0.4943360332055458, 'roc_auc': 0.5011646154774424, 'average_precision': 0.5136591364412043, 'mcc': 0.005840382759490333}
# 第 1 次运行结果: {'RA_accuracy': 0.7774, 'RA_precision': 0.9979, 'RA_recall': 0.556, 'RA_f1': 0.7141, 'RA_roc_auc': 0.993, 'RA_average_precision': 0.9928, 'RA_mcc': 0.6188, 'CN_accuracy': 0.7717, 'CN_precision': 0.9951, 'CN_recall': 0.5461, 'CN_f1': 0.7052, 'CN_roc_auc': 0.9906, 'CN_average_precision': 0.9886, 'CN_mcc': 0.6089, 'JC_accuracy': 0.7748, 'JC_precision': 0.996, 'JC_recall': 0.5517, 'JC_f1': 0.7101, 'JC_roc_auc': 0.9888, 'JC_average_precision': 0.9878, 'JC_mcc': 0.614, 'AA_accuracy': 0.7762, 'AA_precision': 0.9957, 'AA_recall': 0.5548, 'AA_f1': 0.7126, 'AA_roc_auc': 0.9918, 'AA_average_precision': 0.991, 'AA_mcc': 0.6161, 'PA_accuracy': 0.752, 'PA_precision': 0.7537, 'PA_recall': 0.7485, 'PA_f1': 0.7511, 'PA_roc_auc': 0.8314, 'PA_average_precision': 0.8471, 'PA_mcc': 0.5039, 'HI_accuracy': 0.5024, 'HI_precision': 0.5025, 'HI_recall': 0.4868, 'HI_f1': 0.4945, 'HI_roc_auc': 0.4986, 'HI_average_precision': 0.5137, 'HI_mcc': 0.0049}
#
# === 运行 2/10 ===
#
# ----- Fold 1/5 -----
# RA - 折1结果: {'accuracy': 0.7772709242364141, 'precision': 0.9982688391038697, 'recall': 0.5555051850172834, 'f1': 0.7138020169658135, 'roc_auc': 0.9924519343796464, 'average_precision': 0.9923525572703177, 'mcc': 0.6187296030563262}
# CN - 折1结果: {'accuracy': 0.7748625828752762, 'precision': 0.995302767282753, 'recall': 0.552331841106137, 'f1': 0.7104227405247814, 'roc_auc': 0.9900878986194342, 'average_precision': 0.9882813237548147, 'mcc': 0.6138751053972367}
# AA - 折5结果: {'accuracy': 0.778051683100986, 'precision': 0.9970621011042448, 'recall': 0.5577467981412219, 'f1': 0.7153396082421776, 'roc_auc': 0.9926438954994972, 'average_precision': 0.9921175031578905, 'mcc': 0.6194766021586302}
# PA - 折5结果: {'accuracy': 0.7528901734104047, 'precision': 0.7539407044898424, 'recall': 0.7508217159696249, 'f1': 0.752377977796076, 'roc_auc': 0.8327825424181841, 'average_precision': 0.8477891501817009, 'mcc': 0.5057846748551612}
# HI - 折5结果: {'accuracy': 0.5023518077751332, 'precision': 0.5024242070214382, 'recall': 0.4874192451547093, 'f1': 0.4948079965482525, 'roc_auc': 0.4982247923314705, 'average_precision': 0.5148472155288996, 'mcc': 0.004705714592322329}
# 第 2 次运行结果: {'RA_accuracy': 0.7775, 'RA_precision': 0.9977, 'RA_recall': 0.5563, 'RA_f1': 0.7143, 'RA_roc_auc': 0.9929, 'RA_average_precision': 0.9926, 'RA_mcc': 0.6189, 'CN_accuracy': 0.7737, 'CN_precision': 0.9949, 'CN_recall': 0.5503, 'CN_f1': 0.7086, 'CN_roc_auc': 0.9906, 'CN_average_precision': 0.9886, 'CN_mcc': 0.6119, 'JC_accuracy': 0.7741, 'JC_precision': 0.9959, 'JC_recall': 0.5506, 'JC_f1': 0.7091, 'JC_roc_auc': 0.9886, 'JC_average_precision': 0.9869, 'JC_mcc': 0.613, 'AA_accuracy': 0.7765, 'AA_precision': 0.9959, 'AA_recall': 0.5553, 'AA_f1': 0.7131, 'AA_roc_auc': 0.9918, 'AA_average_precision': 0.9909, 'AA_mcc': 0.6167, 'PA_accuracy': 0.7504, 'PA_precision': 0.7519, 'PA_recall': 0.7474, 'PA_f1': 0.7497, 'PA_roc_auc': 0.8302, 'PA_average_precision': 0.846, 'PA_mcc': 0.5008, 'HI_accuracy': 0.4994, 'HI_precision': 0.4994, 'HI_recall': 0.4841, 'HI_f1': 0.4917, 'HI_roc_auc': 0.4964, 'HI_average_precision': 0.5127, 'HI_mcc': -0.0011}
#
# === 运行 3/10 ===
#
# ----- Fold 1/5 -----
# RA - 折1结果: {'accuracy': 0.7786309287697626, 'precision': 0.9978736330498177, 'recall': 0.5584518615062051, 'f1': 0.7161283290338989, 'roc_auc': 0.9930001517677561, 'average_precision': 0.9927401523857708, 'mcc': 0.620681749566061}
# CN - 折1结果: {'accuracy': 0.7736725789085963, 'precision': 0.9936624757231933, 'recall': 0.5508585028616763, 'f1': 0.7087860007291287, 'roc_auc': 0.9901880088868348, 'average_precision': 0.9878095920298944, 'mcc': 0.611409803348984}
# JC - 折1结果: {'accuracy': 0.7772142573808579, 'precision': 0.9953422438234103, 'recall': 0.5570351901173004, 'f1': 0.7143116666061112, 'roc_auc': 0.9884061578745146, 'average_precision': 0.986413665441761, 'mcc': 0.6175259546221621}
# AA - 折1结果: {'accuracy': 0.7769875899586332, 'precision': 0.9949372215471851, 'recall': 0.5568085226950756, 'f1': 0.7140210006176653, 'roc_auc': 0.9914970896751367, 'average_precision': 0.9903548947900508, 'mcc': 0.6170210274311382}
# 第 3 次运行结果: {'RA_accuracy': 0.7779, 'RA_precision': 0.9979, 'RA_recall': 0.557, 'RA_f1': 0.715, 'RA_roc_auc': 0.9928, 'RA_average_precision': 0.9925, 'RA_mcc': 0.6196, 'CN_accuracy': 0.7729, 'CN_precision': 0.9943, 'CN_recall': 0.5489, 'CN_f1': 0.7073, 'CN_roc_auc': 0.9902, 'CN_average_precision': 0.9881, 'CN_mcc': 0.6105, 'JC_accuracy': 0.7747, 'JC_precision': 0.9956, 'JC_recall': 0.5519, 'JC_f1': 0.7101, 'JC_roc_auc': 0.9883, 'JC_average_precision': 0.9868, 'JC_mcc': 0.6138, 'AA_accuracy': 0.7765, 'AA_precision': 0.9953, 'AA_recall': 0.5556, 'AA_f1': 0.7131, 'AA_roc_auc': 0.9915, 'AA_average_precision': 0.9905, 'AA_mcc': 0.6164, 'PA_accuracy': 0.7504, 'PA_precision': 0.752, 'PA_recall': 0.7472, 'PA_f1': 0.7496, 'PA_roc_auc': 0.8303, 'PA_average_precision': 0.8463, 'PA_mcc': 0.5008, 'HI_accuracy': 0.4993, 'HI_precision': 0.4993, 'HI_recall': 0.4845, 'HI_f1': 0.4918, 'HI_roc_auc': 0.4962, 'HI_average_precision': 0.5125, 'HI_mcc': -0.0014}
#
# === 运行 4/10 ===
#
# ----- Fold 1/5 -----
# RA - 折1结果: {'accuracy': 0.7789142630475435, 'precision': 0.9984808588211465, 'recall': 0.5586785289284297, 'f1': 0.7164710584644454, 'roc_auc': 0.992932438616336, 'average_precision': 0.9929187843294686, 'mcc': 0.6213513846551348}
# CN - 折1结果: {'accuracy': 0.7743242477474925, 'precision': 0.9956993651443784, 'recall': 0.5510285034283448, 'f1': 0.7094444241783096, 'roc_auc': 0.9905466988114304, 'average_precision': 0.9889173378986202, 'mcc': 0.6131946015300931}
# JC - 折1结果: {'accuracy': 0.7774975916586389, 'precision': 0.9959489568563905, 'recall': 0.5572618575395252, 'f1': 0.7146542640165692, 'roc_auc': 0.9883060219180538, 'average_precision': 0.9872614151460722, 'mcc': 0.6181953942820388}
# AA - 折1结果: {'accuracy': 0.777837592791976, 'precision': 0.996556613327932, 'recall': 0.5576018586728623, 'f1': 0.7150902946840595, 'roc_auc': 0.9917846401699146, 'average_precision': 0.9912881380354601, 'mcc': 0.6189528319715819}
# PA - 折1结果: {'accuracy': 0.7533008443361477, 'precision': 0.7546718322698268, 'recall': 0.750609168697229, 'f1': 0.7526350180402852, 'roc_auc': 0.8317720523377737, 'average_precision': 0.847255445107445, 'mcc': 0.5066090296096224}
# HI - 折1结果: {'accuracy': 0.49572165240550803, 'precision': 0.49558814936013557, 'recall': 0.48059160197200657, 'f1': 0.4879746835443038, 'roc_auc': 0.48956589210050777, 'average_precision': 0.5081328214198146, 'mcc': -0.00856061545184161}
#
# ----- Fold 2/5 -----
# RA - 折2结果: {'accuracy': 0

#
# ----- Fold 5/5 -----
# RA - 折5结果: {'accuracy': 0.7771732970644906, 'precision': 0.9981666327154206, 'recall': 0.5553666553326533, 'f1': 0.7136615205359743, 'roc_auc': 0.9927167675661053, 'average_precision': 0.992462237190238, 'mcc': 0.618539690025709}
# CN - 折5结果: {'accuracy': 0.7740847784200385, 'precision': 0.9938731747166343, 'recall': 0.5515697608523178, 'f1': 0.7094281861583877, 'roc_auc': 0.990198715069982, 'average_precision': 0.9878325162010944, 'mcc': 0.6121272819671764}
# JC - 折5结果: {'accuracy': 0.7705145642071858, 'precision': 0.9948170415673266, 'recall': 0.5438626317579055, 'f1': 0.7032572454475506, 'roc_auc': 0.9880516851563437, 'average_precision': 0.9861656213436338, 'mcc': 0.6069730822250524}
# AA - 折5结果: {'accuracy': 0.7754731950583702, 'precision': 0.9951110205744551, 'recall': 0.5536665533265329, 'f1': 0.7114768424118847, 'roc_auc': 0.9913947341657454, 'average_precision': 0.9902478547820495, 'mcc': 0.6147457438591232}
# PA - 折5结果: {'accuracy': 0.7555536665533266, 'precision': 0.757259398710708, 'recall': 0.7522384676413918, 'f1': 0.7547405828002843, 'roc_auc': 0.8320480587216736, 'average_precision': 0.847398512396049, 'mcc': 0.5111185681721812}
# HI - 折5结果: {'accuracy': 0.49773319732517285, 'precision': 0.4976503759398496, 'recall': 0.4801088065283917, 'f1': 0.4887222382463225, 'roc_auc': 0.4948187546358754, 'average_precision': 0.5114982354341935, 'mcc': -0.004536424426192934}
# 第 5 次运行结果: {'RA_accuracy': 0.7776, 'RA_precision': 0.9977, 'RA_recall': 0.5564, 'RA_f1': 0.7144, 'RA_roc_auc': 0.9926, 'RA_average_precision': 0.9923, 'RA_mcc': 0.619, 'CN_accuracy': 0.7718, 'CN_precision': 0.9943, 'CN_recall': 0.5468, 'CN_f1': 0.7055, 'CN_roc_auc': 0.9901, 'CN_average_precision': 0.9879, 'CN_mcc': 0.6088, 'JC_accuracy': 0.7743, 'JC_precision': 0.9951, 'JC_recall': 0.5514, 'JC_f1': 0.7096, 'JC_roc_auc': 0.988, 'JC_average_precision': 0.9862, 'JC_mcc': 0.613, 'AA_accuracy': 0.7762, 'AA_precision': 0.9952, 'AA_recall': 0.555, 'AA_f1': 0.7126, 'AA_roc_auc': 0.9913, 'AA_average_precision': 0.9903, 'AA_mcc': 0.6159, 'PA_accuracy': 0.752, 'PA_precision': 0.7535, 'PA_recall': 0.749, 'PA_f1': 0.7512, 'PA_roc_auc': 0.8309, 'PA_average_precision': 0.8459, 'PA_mcc': 0.504, 'HI_accuracy': 0.5015, 'HI_precision': 0.5016, 'HI_recall': 0.486, 'HI_f1': 0.4937, 'HI_roc_auc': 0.4978, 'HI_average_precision': 0.5136, 'HI_mcc': 0.0031}
#
# === 运行 6/10 ===
#
# ----- Fold 1/5 -----
# RA - 折1结果: {'accuracy': 0
# PA - 折4结果: {'accuracy': 0.7497874992916643, 'precision': 0.7511680911680911, 'recall': 0.7470391567971894, 'f1': 0.7490979344830525, 'roc_auc': 0.8295059930474036, 'average_precision': 0.8443508810532988, 'mcc': 0.49958254572041544}
# HI - 折4结果: {'accuracy': 0.5010200034000113, 'precision': 0.5010533707865169, 'recall': 0.48518161727205755, 'f1': 0.4929897797610479, 'roc_auc': 0.4971287369582782, 'average_precision': 0.51212119303334, 'mcc': 0.002041031060578382}
#
# ----- Fold 5/5 -----
# RA - 折5结果: {'accuracy': 0.7779100079338094, 'precision': 0.9981714750101585, 'recall': 0.5568400770712909, 'f1': 0.7148781375045471, 'roc_auc': 0.9925777788157336, 'average_precision': 0.9924498473996856, 'mcc': 0.619680495076012}
# CN - 折5结果: {'accuracy': 0.7702312138728323, 'precision': 0.9956345494231369, 'recall': 0.5428425705542332, 'f1': 0.7026075475849929, 'roc_auc': 0.9900843151424026, 'average_precision': 0.988225210747403, 'mcc': 0.6068484988278874}
# JC - 折5结果: {'accuracy': 0.7764365861951718, 'precision': 0.9959333062220415, 'recall': 0.5551399750651705, 'f1': 0.7129029910486864, 'roc_auc': 0.9881974164435737, 'average_precision': 0.9868960714046631, 'mcc': 0.616548790974123}
# AA - 折5结果: {'accuracy': 0.7769466167970078, 'precision': 0.9964445347419748, 'recall': 0.5558766859344894, 'f1': 0.7136413241178611, 'roc_auc': 0.9913475765514461, 'average_precision': 0.9906665657149814, 'mcc': 0.6175323367529507}
# PA - 折5结果: {'accuracy': 0.7485549132947977, 'precision': 0.7494880546075086, 'recall': 0.7466848010880652, 'f1': 0.7480838017373531, 'roc_auc': 0.8292988764296957, 'average_precision': 0.8460399570195487, 'mcc': 0.4971133037300226}
# HI - 折5结果: {'accuracy': 0.49702482148928934, 'precision': 0.4969442989348699, 'recall': 0.4838490309418565, 'f1': 0.4903092428288397, 'roc_auc': 0.4922872732672246, 'average_precision': 0.5108821477075028, 'mcc': -0.005952424079308203}
# 第 9 次运行结果: {'RA_accuracy': 0.7779, 'RA_precision': 0.998, 'RA_recall': 0.5569, 'RA_f1': 0.7149, 'RA_roc_auc': 0.9925, 'RA_average_precision': 0.9923, 'RA_mcc': 0.6196, 'CN_accuracy': 0.7735, 'CN_precision': 0.9952, 'CN_recall': 0.5497, 'CN_f1': 0.7082, 'CN_roc_auc': 0.99, 'CN_average_precision': 0.988, 'CN_mcc': 0.6117, 'JC_accuracy': 0.7743, 'JC_precision': 0.996, 'JC_recall': 0.5509, 'JC_f1': 0.7094, 'JC_roc_auc': 0.9881, 'JC_average_precision': 0.9867, 'JC_mcc': 0.6134, 'AA_accuracy': 0.7768, 'AA_precision': 0.996, 'AA_recall': 0.5558, 'AA_f1': 0.7135, 'AA_roc_auc': 0.9913, 'AA_average_precision': 0.9904, 'AA_mcc': 0.6171, 'PA_accuracy': 0.7493, 'PA_precision': 0.7507, 'PA_recall': 0.7465, 'PA_f1': 0.7486, 'PA_roc_auc': 0.8294, 'PA_average_precision': 0.8459, 'PA_mcc': 0.4986, 'HI_accuracy': 0.4999, 'HI_precision': 0.4999, 'HI_recall': 0.4838, 'HI_f1': 0.4917, 'HI_roc_auc': 0.495, 'HI_average_precision': 0.5118, 'HI_mcc': -0.0002}
#
# === 运行 10/10 ===
#
# ----- Fold 1/5 -----
# RA - 折1结果: {'accuracy': 0.7769025896752989, 'precision': 0.9980633982264805, 'recall': 0.5548818496061654, 'f1': 0.7132347585403161, 'roc_auc': 0.9926147773319308, 'average_precision': 0.9924399269981791, 'mcc': 0.6180818401764125}
# CN - 折1结果: {'accuracy': 0.7737575791919307, 'precision': 0.9954871794871795, 'recall': 0.5500085000283335, 'f1': 0.7085447311749462, 'roc_auc': 0.9902864702376872, 'average_precision': 0.9884144411096314, 'mcc': 0.6122379872040447}
# JC - 折1结果: {'accuracy': 0.7754859182863942, 'precision': 0.9955152379981653, 'recall': 0.5534651782172607, 'f1': 0.7114137956151213, 'roc_auc': 0.98823682522341, 'average_precision': 0.9871796307447303, 'mcc': 0.6149196492413035}
# AA - 折1结果: {'accuracy': 0.7757692525641752, 'precision': 0.9960248700438283, 'recall': 0.5537485124950416, 'f1': 0.7117779882001602, 'roc_auc': 0.9914998640936328, 'average_precision': 0.9907624646524882, 'mcc': 0.6155520874283252}
# PA - 折1结果: {'accuracy': 0.7537258457528192, 'precision': 0.7554338524730446, 'recall': 0.7503825012750043, 'f1': 0.7528997043438708, 'roc_auc': 0.8327171014825353, 'average_precision': 0.8489426685295103, 'mcc': 0.5074630364276804}
# HI - 折1结果: {'accuracy': 0.502465008216694, 'precision': 0.5025580711555425, 'recall': 0.4842749475831586, 'f1': 0.4932471430220478, 'roc_auc': 0.49936915696105344, 'average_precision': 0.5142989975024598, 'mcc': 0.004933282146377224}
#
# ----- Fold 2/5 -----
# RA - 折2结果: {'accuracy': 0.7777525925086417, 'precision': 0.997563699116841, 'recall': 0.5568651895506318, 'f1': 0.7147428903920285, 'roc_auc': 0.9918989564875776, 'average_precision': 0.991683924244328, 'mcc': 0.6192053273259692}
# CN - 折2结果: {'accuracy': 0.7722559075196918, 'precision': 0.9943409815824673, 'recall': 0.5476284920949737, 'f1': 0.7062778630417306, 'roc_auc': 0.9894759017172394, 'average_precision': 0.9873061154207409, 'mcc': 0.6094801715665732}
# JC - 折2结果: {'accuracy': 0.7718025726752422, 'precision': 0.9956598119251834, 'recall': 0.5459851532838442, 'f1': 0.7052408139364661, 'roc_auc': 0.9875492206004979, 'average_precision': 0.9857238315014527, 'mcc': 0.6092842332365856}
# AA - 折2结果: {'accuracy': 0.7765059216864056, 'precision': 0.9953304233072785, 'recall': 0.5556185187283957, 'f1': 0.7131427740199288, 'roc_auc': 0.990656776434169, 'average_precision': 0.9896753578172324, 'mcc': 0.6164260725669829}
# PA - 折2结果: {'accuracy': 0.7508075026916756, 'precision': 0.7523375142531357, 'recall': 0.7477758259194197, 'f1': 0.7500497342768636, 'roc_auc': 0.8293203366041404, 'average_precision': 0.8453595828732158, 'mcc': 0.5016242263888919}
# HI - 折4结果: {'accuracy': 0.4992349974499915, 'precision': 0.499204619100925, 'recall': 0.4801382671275571, 'f1': 0.48948584633160025, 'roc_auc': 0.4953846440476783, 'average_precision': 0.5111112906631565, 'mcc': -0.001531122262556678}
#
# ----- Fold 5/5 -----
# RA - 折5结果: {'accuracy': 0.777796667800068, 'precision': 0.997766043866775, 'recall': 0.5568400770712909, 'f1': 0.7147741325380083, 'roc_auc': 0.9927946415384795, 'average_precision': 0.9924448724504613, 'mcc': 0.6193506378059918}
# CN - 折5结果: {'accuracy': 0.7730647172163663, 'precision': 0.9945601970645592, 'recall': 0.5491329479768786, 'f1': 0.7075833363759173, 'roc_auc': 0.9904347600611978, 'average_precision': 0.9881907338570416, 'mcc': 0.6108133979319114}
# JC - 折5结果: {'accuracy': 0.776379916128301, 'precision': 0.9952274573517466, 'recall': 0.555423325399524, 'f1': 0.7129555539390412, 'roc_auc': 0.9881684904947862, 'average_precision': 0.9860493013107221, 'mcc': 0.616191974822485}
# AA - 折5结果: {'accuracy': 0.7764932562620424, 'precision': 0.9954305442729489, 'recall': 0.5555366655332653, 'f1': 0.7131010402269586, 'roc_auc': 0.9916289148832553, 'average_precision': 0.99058018192233, 'mcc': 0.6164446678611656}
# PA - 折5结果: {'accuracy': 0.751416751671767, 'precision': 0.7527776195088599, 'recall': 0.7487249234954098, 'f1': 0.7507458021990511, 'roc_auc': 0.831098555701396, 'average_precision': 0.8461152197252759, 'mcc': 0.5028407905036566}
# HI - 折5结果: {'accuracy': 0.49895160376289244, 'precision': 0.49892759840009276, 'recall': 0.48775926555593335, 'f1': 0.4932802246611457, 'roc_auc': 0.4978941703746926, 'average_precision': 0.5162177469809381, 'mcc': -0.0020973179955386645}
# 第 10 次运行结果: {'RA_accuracy': 0.7776, 'RA_precision': 0.9977, 'RA_recall': 0.5565, 'RA_f1': 0.7145, 'RA_roc_auc': 0.9925, 'RA_average_precision': 0.9922, 'RA_mcc': 0.6191, 'CN_accuracy': 0.7737, 'CN_precision': 0.9946, 'CN_recall': 0.5504, 'CN_f1': 0.7086, 'CN_roc_auc': 0.9901, 'CN_average_precision': 0.9879, 'CN_mcc': 0.6118, 'JC_accuracy': 0.7738, 'JC_precision': 0.9956, 'JC_recall': 0.55, 'JC_f1': 0.7086, 'JC_roc_auc': 0.9881, 'JC_average_precision': 0.9866, 'JC_mcc': 0.6123, 'AA_accuracy': 0.7763, 'AA_precision': 0.9954, 'AA_recall': 0.5552, 'AA_f1': 0.7128, 'AA_roc_auc': 0.9913, 'AA_average_precision': 0.9903, 'AA_mcc': 0.6162, 'PA_accuracy': 0.7512, 'PA_precision': 0.7528, 'PA_recall': 0.7481, 'PA_f1': 0.7504, 'PA_roc_auc': 0.8302, 'PA_average_precision': 0.846, 'PA_mcc': 0.5024, 'HI_accuracy': 0.4996, 'HI_precision': 0.4996, 'HI_recall': 0.482, 'HI_f1': 0.4907, 'HI_roc_auc': 0.4964, 'HI_average_precision': 0.5125, 'HI_mcc': -0.0008}
# ✅ 实验结果已保存至: facebook_RA_CN_JC_AA_PA_HI.xlsx
